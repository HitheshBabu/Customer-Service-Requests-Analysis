# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
#import dataset -> Question 1
dataset = pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
#original copy, which will be kept unaffected
dataset_original = pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
# Out:
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dataset_original
# Out:
#         Unique Key            Created Date             Closed Date Agency  \
# 0         32310363  12/31/2015 11:59:45 PM           01-01-16 0:55   NYPD
# 1         32309934  12/31/2015 11:59:44 PM           01-01-16 1:26   NYPD
# 2         32309159  12/31/2015 11:59:29 PM           01-01-16 4:51   NYPD
# 3         32305098  12/31/2015 11:57:46 PM           01-01-16 7:43   NYPD
# 4         32306529  12/31/2015 11:56:58 PM           01-01-16 3:24   NYPD
# ...            ...                     ...                     ...    ...
# 300693    30281872  03/29/2015 12:33:41 AM                     NaN   NYPD
# 300694    30281230  03/29/2015 12:33:28 AM  03/29/2015 02:33:59 AM   NYPD
# 300695    30283424  03/29/2015 12:33:03 AM  03/29/2015 03:40:20 AM   NYPD
# 300696    30280004  03/29/2015 12:33:02 AM  03/29/2015 04:38:35 AM   NYPD
# 300697    30281825  03/29/2015 12:33:01 AM  03/29/2015 04:41:50 AM   NYPD
#
#                             Agency Name           Complaint Type  \
# ...

# %%
dataset.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
dataset.shape
# Out:
# (300698, 53)

# %%
dataset.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough',
#        'School Name', 'School Number', 'School Region', 'School Code',
#        'School Phone Number', 'School Address', 'School City', 'School State',
#        'School Zip', 'School Not Found', 'School or Citywide Complaint',
#        'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location',
#        'Bridge Highway Name', 'Bridge Highway Direction', 'Road Ramp',
# ...

# %%
dataset.isnull().sum()
# Out:
# Unique Key                             0
# Created Date                           0
# Closed Date                         2164
# Agency                                 0
# Agency Name                            0
# Complaint Type                         0
# Descriptor                          5914
# Location Type                        131
# Incident Zip                        2615
# Incident Address                   44410
# Street Name                        44410
# Cross Street 1                     49279
# Cross Street 2                     49779
# Intersection Street 1             256840
# Intersection Street 2             257336
# Address Type                        2815
# City                                2614
# Landmark                          300349
# Facility Type                       2171
# Status                                 0
# Due Date                               3
# Resolution Description                 0
# Resolution Action Updated Date      2187
# ...

# %%
#Closed data column is important and we have missing values , so we extract that alone separatley
dataset[dataset['Closed Date'].isnull()]
# Out:
#         Unique Key            Created Date Closed Date Agency  \
# 416       32305700  12/31/2015 02:16:04 PM         NaN   NYPD
# 611       32309308  12/31/2015 09:58:06 AM         NaN   NYPD
# 1648      32303348  12/30/2015 05:13:42 AM         NaN   NYPD
# 1816      32294519  12/29/2015 10:44:50 PM         NaN   NYPD
# 1965      32296487  12/29/2015 07:09:13 PM         NaN   NYPD
# ...            ...                     ...         ...    ...
# 300273    30287350  03/29/2015 02:40:19 PM         NaN   NYPD
# 300492    30284963  03/29/2015 08:50:15 AM         NaN   NYPD
# 300496    30285492  03/29/2015 08:44:13 AM         NaN   NYPD
# 300620    30282717  03/29/2015 01:55:35 AM         NaN   NYPD
# 300693    30281872  03/29/2015 12:33:41 AM         NaN   NYPD
#
#                             Agency Name           Complaint Type  \
# 416     New York City Police Department          Illegal Parking
# 611     New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
#unique key for future exploration
dataset[dataset['Unique Key'] == 32305700]
# Out:
#      Unique Key            Created Date Closed Date Agency  \
# 416    32305700  12/31/2015 02:16:04 PM         NaN   NYPD
#
#                          Agency Name   Complaint Type  \
# 416  New York City Police Department  Illegal Parking
#
#                         Descriptor    Location Type  Incident Zip  \
# 416  Posted Parking Sign Violation  Street/Sidewalk           NaN
#
#       Incident Address  ... Bridge Highway Name Bridge Highway Direction  \
# 416  5426-5526 90TH ST  ...                 NaN                      NaN
#
#     Road Ramp Bridge Highway Segment Garage Lot Name Ferry Direction  \
# 416       NaN                    NaN             NaN             NaN
#
#     Ferry Terminal Name Latitude Longitude Location
# 416                 NaN      NaN       NaN      NaN
#
# [1 rows x 53 columns]

# %%
#datatype of each columns
dataset.dtypes
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                      float64
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Description             object
# ...

# %%
#Creating a new cloumn 'Requesting closure time' ---> Question 2
import datetime as dt
import time , datetime

# %%
#Convert closed time to datetime type
dataset['Closed Date'] = pd.to_datetime(dataset['Closed Date'])
dataset['Closed Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Convert closed time to datetime type
dataset['Created Date'] = pd.to_datetime(dataset['Created Date'])
dataset['Created Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Create new column 'Closing time' bu subracting both created and closed time
dataset['Request_Closing_Time'] = dataset['Closed Date'] - dataset['Created Date']

dataset['Request_Closing_Time'].head()
# Out:
# 0   00:55:15
# 1   01:26:16
# 2   04:51:31
# 3   07:45:14
# 4   03:27:02
# Name: Request_Closing_Time, dtype: timedelta64[ns]

# %%
#Any 4 Insigihts ---> Q3
#Insight 1 --> Categorsizing based on Request_closing_time
# <2 hrs - Fast ; 2-4 hrs - Acceptable ; 4-6 hrs slow ; >6hrs very slow
# Creating new cloumn for requestin clsoing hours

# Create a fn to to convert change in time to Hours
def toHr(timeDel):
    days = timeDel.days
    hours = round(timeDel.seconds/3600, 2)
    result = (days * 24) + hours
    return result

# %%
# Testing of function with days
test_days = dataset[dataset['Unique Key'] == 32122264]['Request_Closing_Time']
print(toHr(test_days[27704]))
print(test_days[27704])
print(test_days.dtype)
# Out:
# 145.08
# 6 days 01:05:00
# timedelta64[ns]

# %%
# Apply this function to every row of column Request_Closing_Time
dataset['Request_Closing_In_Hr'] = dataset['Request_Closing_Time'].apply(toHr)

dataset['Request_Closing_In_Hr'].head()
# Out:
# 0    0.92
# 1    1.44
# 2    4.86
# 3    7.75
# 4    3.45
# Name: Request_Closing_In_Hr, dtype: float64

# %%
import math

# %%
#Fn to categorise hours
def hrToCategory(hr):
    if (math.isnan(hr)):
        return 'Unspecified'
    elif (hr < 2.0):
        return 'Fast'
    elif (4.0 > hr >= 2.0):
        return 'Acceptable'
    elif (6.0 > hr >= 4.0):
        return 'Slow'
    else:
        return 'Very Slow'
    
# Testing function
print(hrToCategory(1.99))

# Create new column Request_Closing_Time_Category and apply function on column Request_Closing_In_Hr

dataset['Request_Closing_Time_Category'] = dataset['Request_Closing_In_Hr'].apply(hrToCategory)

dataset['Request_Closing_Time_Category'].head()
# Out:
# Fast
# 0          Fast
# 1          Fast
# 2          Slow
# 3     Very Slow
# 4    Acceptable
# Name: Request_Closing_Time_Category, dtype: object

# %%
dataset['Request_Closing_Time_Category'].value_counts()

# Create Bar plot for Request_Closing_Time_Category
dataset['Request_Closing_Time_Category'].value_counts().plot(kind="barh", color=list('rgbkymc'), alpha=0.7, figsize=(15,3))
plt.show()

# %%
dataset.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
# Insight 2 - To check with Month have Complain creation most and least

#create one column with Create_Month name

# Created Series for months in text format
monthSeries = pd.Series({1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun', 7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'})
print(monthSeries)
print(monthSeries[12])
# Out:
# 1     Jan
# 2     Feb
# 3     Mar
# 4     Apr
# 5     May
# 6     Jun
# 7     Jul
# 8     Aug
# 9     Sep
# 10    Oct
# 11    Nov
# 12    Dec
# dtype: object
# Dec

# %%
dataset['Created Date'].dtype

# Function to fetch month from Created Date column

def getMonth(cDate):
    a = str(cDate)
    datee = datetime.datetime.strptime(a, "%Y-%m-%d %H:%M:%S")
    return monthSeries[datee.month]

# Test function getMonth
print(dataset['Created Date'][0])
print(getMonth(dataset['Created Date'][0]))
# Out:
# 2015-12-31 23:59:45
# Dec

# %%
# Created new column Created_Month and kept all text format months in that column

dataset['Created_Month'] = dataset['Created Date'].apply(getMonth)
dataset['Created_Month']
# Out:
# 0         Dec
# 1         Dec
# 2         Dec
# 3         Dec
# 4         Dec
#          ...
# 300693    Mar
# 300694    Mar
# 300695    Mar
# 300696    Mar
# 300697    Mar
# Name: Created_Month, Length: 300698, dtype: object

# %%
dataset.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
dataset['Created_Month'].value_counts()

# Create Bar plot for Complain Created Month , it prove Most count is in May month and least is in March and in January there is no any complain
dataset['Created_Month'].value_counts().plot(kind="barh", color=list('rgbkymc'), alpha=0.7, figsize=(15,3))
plt.show()

# %%
#to confirm Jan has no complain we use original dataset
dataset_original[dataset_original['Created Date'].str.startswith('01/')]
# Out:
# Empty DataFrame
# Columns: [Unique Key, Created Date, Closed Date, Agency, Agency Name, Complaint Type, Descriptor, Location Type, Incident Zip, Incident Address, Street Name, Cross Street 1, Cross Street 2, Intersection Street 1, Intersection Street 2, Address Type, City, Landmark, Facility Type, Status, Due Date, Resolution Description, Resolution Action Updated Date, Community Board, Borough, X Coordinate (State Plane), Y Coordinate (State Plane), Park Facility Name, Park Borough, School Name, School Number, School Region, School Code, School Phone Number, School Address, School City, School State, School Zip, School Not Found, School or Citywide Complaint, Vehicle Type, Taxi Company Borough, Taxi Pick Up Location, Bridge Highway Name, Bridge Highway Direction, Road Ramp, Bridge Highway Segment, Garage Lot Name, Ferry Direction, Ferry Terminal Name, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 53 columns]

# %%
# Insight - 3
# Check count in each complain type in descending order
dataset['Complaint Type'].value_counts()
# Out:
# Blocked Driveway             77044
# Illegal Parking              75361
# Noise - Street/Sidewalk      48612
# Noise - Commercial           35577
# Derelict Vehicle             17718
# Noise - Vehicle              17083
# Animal Abuse                  7778
# Traffic                       4498
# Homeless Encampment           4416
# Noise - Park                  4042
# Vending                       3802
# Drinking                      1280
# Noise - House of Worship       931
# Posting Advertisement          650
# Urinating in Public            592
# Bike/Roller/Skate Chronic      427
# Panhandling                    307
# Disorderly Youth               286
# Illegal Fireworks              168
# Graffiti                       113
# Agency Issues                    6
# Squeegee                         4
# Ferry Complaint                  2
# Animal in a Park                 1
# Name: Complaint Type, dtype: int64

# %%
# Create Bar plot
dataset['Complaint Type'].value_counts().plot(kind="barh", color=list('rgbkymc'), alpha=0.7, figsize=(15,10))
plt.show()

# %%
# Insight 4
# Let's check count for status type
dataset['Status'].value_counts()
# Out:
# Closed      298471
# Open          1439
# Assigned       786
# Draft            2
# Name: Status, dtype: int64

# %%
# Draw Bar lot for Status
from matplotlib import style
style.use('ggplot')
dataset['Status'].value_counts().plot(kind='bar', color=list('rgbkymc'))
plt.show()

# %%
# Order the complaint types based on the average ‘Request_Closing_Time’, grouping them for different locations. ---> Q4



# For location we can choose here City, so first check if there is missing values there
dataset['City'].isnull().sum()
# Out:
# 2614

# %%
# Fill all missing value with some default value here i used - Not Available
dataset['City'].fillna('Not Available', inplace=True)

# %%
dataset['City'].head()
# Out:
# 0    NEW YORK
# 1     ASTORIA
# 2       BRONX
# 3       BRONX
# 4    ELMHURST
# Name: City, dtype: object

# %%
dataset['City']
# Out:
# 0              NEW YORK
# 1               ASTORIA
# 2                 BRONX
# 3                 BRONX
# 4              ELMHURST
#               ...
# 300693    Not Available
# 300694    RICHMOND HILL
# 300695         BROOKLYN
# 300696            BRONX
# 300697         NEW YORK
# Name: City, Length: 300698, dtype: object

# %%
# Group them for City (location) first and Complain Type in that
dataset_grouped = dataset.groupby(['City', 'Complaint Type'])

# %%
# get average of this grouped dataframe, and get Request_Closing_Time column from there
dataset_mean = dataset_grouped.mean()['Request_Closing_In_Hr']
dataset_mean.isnull().sum()
# Out:
# 4

# %%
# Group by City(location) first and then Complain Type and showing average of Request Closing in Hour
dataset_grouped = dataset.groupby(['City','Complaint Type']).agg({'Request_Closing_In_Hr': 'mean'})
dataset_grouped
# Out:
#                                   Request_Closing_In_Hr
# City     Complaint Type
# ARVERNE  Animal Abuse                          2.153158
#          Blocked Driveway                      2.526000
#          Derelict Vehicle                      2.968889
#          Disorderly Youth                      3.595000
#          Drinking                              0.240000
# ...                                                 ...
# Woodside Blocked Driveway                      6.405455
#          Derelict Vehicle                      4.965000
#          Illegal Parking                       5.219500
#          Noise - Commercial                    2.390000
#          Noise - Street/Sidewalk               3.410000
#
# [782 rows x 1 columns]

# %%
# Check if any value is NaN
dataset_grouped[dataset_grouped['Request_Closing_In_Hr'].isnull()]
# Out:
#                                         Request_Closing_In_Hr
# City          Complaint Type
# Not Available Ferry Complaint                             NaN
#               Noise - House of Worship                    NaN
#               Panhandling                                 NaN
#               Posting Advertisement                       NaN

# %%
# Check total rows
print(dataset_grouped)
# Out:
#                                   Request_Closing_In_Hr
# City     Complaint Type
# ARVERNE  Animal Abuse                          2.153158
#          Blocked Driveway                      2.526000
#          Derelict Vehicle                      2.968889
#          Disorderly Youth                      3.595000
#          Drinking                              0.240000
# ...                                                 ...
# Woodside Blocked Driveway                      6.405455
#          Derelict Vehicle                      4.965000
#          Illegal Parking                       5.219500
#          Noise - Commercial                    2.390000
#          Noise - Street/Sidewalk               3.410000
#
# [782 rows x 1 columns]

# %%
# drop null values from this group
dataset_grouped_withoutna = dataset_grouped.dropna()

# %%
# verify if new group has null values
dataset_grouped_withoutna.isnull().sum()
# Out:
# Request_Closing_In_Hr    0
# dtype: int64

# %%
# verify number of rows after dropping null values
print(dataset_grouped_withoutna)
# Out:
#                                   Request_Closing_In_Hr
# City     Complaint Type
# ARVERNE  Animal Abuse                          2.153158
#          Blocked Driveway                      2.526000
#          Derelict Vehicle                      2.968889
#          Disorderly Youth                      3.595000
#          Drinking                              0.240000
# ...                                                 ...
# Woodside Blocked Driveway                      6.405455
#          Derelict Vehicle                      4.965000
#          Illegal Parking                       5.219500
#          Noise - Commercial                    2.390000
#          Noise - Street/Sidewalk               3.410000
#
# [778 rows x 1 columns]

# %%
# Sorting by column - Request_Closing_In_Hr for City on grouped
dataset_sorted = dataset_grouped_withoutna.sort_values(['City', 'Request_Closing_In_Hr'])
dataset_sorted
# Out:
#                                   Request_Closing_In_Hr
# City     Complaint Type
# ARVERNE  Drinking                              0.240000
#          Vending                               0.480000
#          Urinating in Public                   0.690000
#          Panhandling                           1.030000
#          Noise - Park                          1.285000
# ...                                                 ...
# Woodside Noise - Commercial                    2.390000
#          Noise - Street/Sidewalk               3.410000
#          Derelict Vehicle                      4.965000
#          Illegal Parking                       5.219500
#          Blocked Driveway                      6.405455
#
# [778 rows x 1 columns]

# %%
    # Question 5: Perform a statistical test for the following:
# Please note: For the below statements you need to state the Null and Alternate and then provide a statistical test to accept or reject the Null Hypothesis along with the corresponding ‘p-value’.

# Whether the average response time across complaint types is similar or not (overall)
# Are the type of complaint or service requested and location related?

# %%
import scipy.stats as stats
from math import sqrt

# %%
##### Try ANOVA for first one

# H0 : All Complain Types average response time mean is similar
# H1 : Not similar

dataset['Complaint Type'].value_counts()
# Out:
# Blocked Driveway             77044
# Illegal Parking              75361
# Noise - Street/Sidewalk      48612
# Noise - Commercial           35577
# Derelict Vehicle             17718
# Noise - Vehicle              17083
# Animal Abuse                  7778
# Traffic                       4498
# Homeless Encampment           4416
# Noise - Park                  4042
# Vending                       3802
# Drinking                      1280
# Noise - House of Worship       931
# Posting Advertisement          650
# Urinating in Public            592
# Bike/Roller/Skate Chronic      427
# Panhandling                    307
# Disorderly Youth               286
# Illegal Fireworks              168
# Graffiti                       113
# Agency Issues                    6
# Squeegee                         4
# Ferry Complaint                  2
# Animal in a Park                 1
# Name: Complaint Type, dtype: int64

# %%
top5_complaints_type = dataset['Complaint Type'].value_counts()[:5]
top5_complaints_type
# Out:
# Blocked Driveway           77044
# Illegal Parking            75361
# Noise - Street/Sidewalk    48612
# Noise - Commercial         35577
# Derelict Vehicle           17718
# Name: Complaint Type, dtype: int64

# %%
top5_complaints_type_names = top5_complaints_type.index
top5_complaints_type_names
# Out:
# Index(['Blocked Driveway', 'Illegal Parking', 'Noise - Street/Sidewalk',
#        'Noise - Commercial', 'Derelict Vehicle'],
#       dtype='object')

# %%
sample_data = dataset.loc[dataset['Complaint Type'].isin(top5_complaints_type_names), ['Complaint Type', 'Request_Closing_In_Hr']]
sample_data.head()
# Out:
#             Complaint Type  Request_Closing_In_Hr
# 0  Noise - Street/Sidewalk                   0.92
# 1         Blocked Driveway                   1.44
# 2         Blocked Driveway                   4.86
# 3          Illegal Parking                   7.75
# 4          Illegal Parking                   3.45

# %%
sample_data.shape
# Out:
# (254312, 2)

# %%
sample_data.isnull().sum()
# Out:
# Complaint Type              0
# Request_Closing_In_Hr    2059
# dtype: int64

# %%
#sample_data[~sample_data.isin(['NaN', 'NaT']).any(axis=1)]
#sample_data[sample_data.isnull()]

sample_data.dropna(how='any', inplace=True)
sample_data.isnull().sum()
# sample_data_without_null[sample_data_without_null.isnull()]
# Out:
# Complaint Type           0
# Request_Closing_In_Hr    0
# dtype: int64

# %%
sample_data.shape
# Out:
# (252253, 2)

# %%
s1 = sample_data[sample_data['Complaint Type'] == top5_complaints_type_names[0]].Request_Closing_In_Hr
s1.head()
# Out:
# 1     1.44
# 2     4.86
# 7     1.80
# 9     1.38
# 10    7.80
# Name: Request_Closing_In_Hr, dtype: float64

# %%
s2 = sample_data[sample_data['Complaint Type'] == top5_complaints_type_names[1]].Request_Closing_In_Hr
s2.head()
# Out:
# 3    7.75
# 4    3.45
# 5    1.89
# 6    1.96
# 8    8.55
# Name: Request_Closing_In_Hr, dtype: float64

# %%
s3 = sample_data[sample_data['Complaint Type'] == top5_complaints_type_names[2]].Request_Closing_In_Hr
s3.head()
# Out:
# 0     0.92
# 12    2.48
# 19    0.78
# 38    0.49
# 54    1.50
# Name: Request_Closing_In_Hr, dtype: float64

# %%
s4 = sample_data[sample_data['Complaint Type'] == top5_complaints_type_names[3]].Request_Closing_In_Hr
s4.head()
# Out:
# 17    0.85
# 18    2.93
# 22    1.26
# 29    2.50
# 30    1.99
# Name: Request_Closing_In_Hr, dtype: float64

# %%
s5 = sample_data[sample_data['Complaint Type'] == top5_complaints_type_names[4]].Request_Closing_In_Hr
s5.head()
# Out:
# 14     10.49
# 151     3.95
# 255     1.36
# 256     4.13
# 295     0.75
# Name: Request_Closing_In_Hr, dtype: float64

# %%
print(s1.isnull().sum())
print(s2.isnull().sum())
print(s3.isnull().sum())
print(s4.isnull().sum())
print(s5.isnull().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
stats.f_oneway(s1, s2, s3, s4, s5)
###We can see pvalue is less than 0.05 so we reject null hypothesis and average response time is not same.
# Out:
# F_onewayResult(statistic=1799.598683238952, pvalue=0.0)

# %%
### Try ChiSquare Test for second one - # Are the type of complaint or service requested and location related?

# H0 : 2 categories - Complain Type and Location is independent means not related
# Ha : 2 categories - Complain Type and Location is dependent means related

# %%
top5_location = dataset['City'].value_counts()[:5]
top5_location
# Out:
# BROOKLYN         98307
# NEW YORK         65994
# BRONX            40702
# STATEN ISLAND    12343
# JAMAICA           7296
# Name: City, dtype: int64

# %%
top5_location_names = top5_location.index
top5_location_names
# Out:
# Index(['BROOKLYN', 'NEW YORK', 'BRONX', 'STATEN ISLAND', 'JAMAICA'], dtype='object')

# %%
sample_data_location_c_type = dataset.loc[(dataset['Complaint Type'].isin(top5_complaints_type_names)) & (dataset['City'].isin(top5_location_names)), ['Complaint Type', 'City']]
sample_data_location_c_type.head()
# Out:
#             Complaint Type      City
# 0  Noise - Street/Sidewalk  NEW YORK
# 2         Blocked Driveway     BRONX
# 3          Illegal Parking     BRONX
# 5          Illegal Parking  BROOKLYN
# 6          Illegal Parking  NEW YORK

# %%
pd.crosstab(sample_data_location_c_type['Complaint Type'], sample_data_location_c_type['City'], margins=True)
# Out:
# City                     BRONX  BROOKLYN  JAMAICA  NEW YORK  STATEN ISLAND  \
# Complaint Type
# Blocked Driveway         12755     28148     2818      2072           2142
# Derelict Vehicle          1953      5181      954       537           1766
# Illegal Parking           7859     27462     1421     12128           4886
# Noise - Commercial        2434     11463      429     14550            678
# Noise - Street/Sidewalk   8892     13356      339     20433            819
# All                      33893     85610     5961     49720          10291
#
# City                        All
# Complaint Type
# Blocked Driveway          47935
# Derelict Vehicle          10391
# Illegal Parking           53756
# Noise - Commercial        29554
# Noise - Street/Sidewalk   43839
# All                      185475

# %%
ch2, p_value, df, exp_frq = stats.chi2_contingency(pd.crosstab(sample_data_location_c_type['Complaint Type'], sample_data_location_c_type['City']))

# %%
print(ch2)
print(p_value)
# Out:
# 40522.79928349593
# 0.0

# %%
#We can see pvalue is less than 0.05 so we reject null hypothesis means complain type and location is not independent.
